# %% [markdown]
# ## Validate log data for Streaming
#
# Let us ensure that we have proper data set to explore Spark Structured Streaming.
# * We will be using the log file generated by **gen_logs** for the demo.
# * Make sure the application is deployed under **/opt/gen_logs**. You can run `ls -ltr /opt/gen_logs/logs` to ensure that **access.log** file exists.
# * You can run `tail_logs.sh` to confirm that data is being written continuously into **/opt/gen_logs/logs/access.log**.

# %%
# !ls -ltr /opt/gen_logs
# Out:
# total 24
# -rwxrwxr-x 1 centos centos   51 Mar 12 17:06 tail_logs.sh
# -rwxrwxr-x 1 centos centos  131 Mar 12 17:06 stop_logs.sh
# -rwxrwxr-x 1 centos centos   76 Mar 12 17:06 start_logs.sh
# drwxrwxr-x 2 centos centos 4096 Mar 12 17:06 lib
# drwxrwxr-x 2 centos centos 4096 Mar 12 17:06 data
# drwxrwxr-x 2 centos centos 4096 Aug 27 00:00 logs

# %%
# !ls -ltr /opt/gen_logs/logs
# Out:
# total 87180
# -rw-rw-r-- 1 centos centos  1371764 Aug 23 13:28 access.log.8.gz
# -rw-rw-r-- 1 centos centos    19929 Aug 23 13:30 access.log.7.gz
# -rw-rw-r-- 1 centos centos    30778 Aug 23 13:42 access.log.6.gz
# -rw-rw-r-- 1 centos centos    18524 Aug 23 13:43 access.log.5.gz
# -rw-rw-r-- 1 centos centos 17643010 Aug 23 13:55 access.log.2
# -rw-rw-r-- 1 centos centos 17650359 Aug 23 13:56 access.log.1-2021082313.backup
# -rw-rw-r-- 1 centos centos      867 Aug 23 13:57 access.log.3.gz
# -rw-rw-r-- 1 centos centos      455 Aug 23 13:57 access.log.2.gz
# -rw-rw-r-- 1 centos centos      163 Aug 23 13:57 access.log.1.gz
# -rw-r--r-- 1 root   root      35501 Aug 24 00:18 access.log.2021-08-24
# -rw-r--r-- 1 root   root   16840588 Aug 25 00:00 access.log.2021-08-25
# -rw-r--r-- 1 root   root   17138283 Aug 26 00:00 access.log.2021-08-26
# -rw-r--r-- 1 root   root   17138001 Aug 27 00:00 access.log.2021-08-27
# -rw-r--r-- 1 root   root    1328783 Aug 27 01:51 access.log
